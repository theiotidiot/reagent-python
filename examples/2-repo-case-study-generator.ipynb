# %% [markdown]
# # _ Case Study
#
# This is a Reagent Analytics project demo, using the API, to answer questions about foreign influence in various entities in ANY open source code repository.
#
# The `reagentpy` Python package facilitates use of the [Reagent API](https://api.reagentanalytics.com) and querying the Reagent version control intelligence database.

# %% [markdown]
# ## Import the `Reagent` object

# %%
from reagentpy import Reagent
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from reagentpy import Reagent
#
# ModuleNotFoundError: No module named 'reagentpy'

# %% [markdown]
# Check the status of the connection.

# %%
Reagent().status().dict()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Reagent().status().dict()
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/site-packages/reagentpy/__init__.py:35, in Reagent.status(self)
#      34 def status(self):
# ---> 35     return GenericClient().get("/status")
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/site-packages/reagentpy/clients/generic.py:5, in GenericClient.__init__(self)
#       4 def __init__(self):
# ----> 5     super().__init__()
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/site-packages/reagentpy/clients/__init__.py:73, in ReagentClient.__init__(self, reagent_api_key)
#      70     self.reagent_api_key = os.getenv("REAGENT_API_KEY")
#      72 # Initialize a new requests session
# ---> 73 self.init_session()
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/site-packages/reagentpy/clients/__init__.py:83, in ReagentClient.init_session(self)
#      81 # Set the authorization header
#      82 if not self.reagent_api_key:
# ---> 83     raise ValueError("Reagnet API key environment variable not set or missing. Try \"reagent login\" to set the API key.")
#      84 self.session.headers.update({
#      85     "Authorization": f"Basic {self.reagent_api_key}"
#      86 })
#      88 # Set user agent
#
# ValueError: Reagnet API key environment variable not set or missing. Try "reagent login" to set the API key.

# %% [markdown]
# Set all required variable names to appropriately constrain query results.

# %%
repo_name = "FILL IN HERE"
entity = "FILL IN HERE"
limit = 50
tz = 0.0

# %% [markdown]
# # Non-Adversarial Threat
#
# There are a number of human factors that influence the likelihood that vulnerabilities are injected into repositories at various points in the open source lifecycle.  These can be used to infer threat that can be quantified, and thus analyzed.  These metrics are all on a sliding scale between from **0 - 10**, 0 meaning that Harbor is unaffected by this issue, and 10 meaning that that all commits exhibit the problem at hand.
#
# ## Threatscoring Breakdown
#
# **Project Fragmentation** is defined as the ratio of files within a repository edited by more than ten developers to files within a repository edited by less than ten developers.  The significance factor for this function is **r = 16**.
#
# **Unfocused Contribution** is measured by taking the average pagerank of each file within a repo.  The significance factor for this function is **r = .4497**.
#
# **Context Switching** is calculated by taking the average weekly density of distinct file communities users commit to each week.  The significance factor for this function is **r = 0.17**.
#
# **Interactive Churn** is the average weekly number of user interactions a file has, scaled by how recent each action is.  The significance factor for this function is **r = 0.16**.

# %%
Reagent().enrichments().threat_score(repo_name).df()
# Out:
#    interactive_churn_score  context_switching_score  \
# 0                     0.16                      0.0
#
#    project_fragmentation_score  unfocused_contribution_score
# 0                     0.151283                      0.258025

# %% [markdown]
# ## What organizations are involved?  What are the affiliations of those organizations?
#
# Analyzing email domains found in the repo yeilds a glimpse into the organizations who are interested in using Harbor.

# %%
Reagent().repo().email_domains(repo_name).df()

# %% [markdown]
# # Adversarial Risk
#
# Describes deliberate attacks by bad actors with intent, capability, and targeting characteristics of any scale.  While all kinds of risk are invaluable in deciding how "safe" a resource is to use, adversarial risk serves as the best way to quantify sources of attack.
#
# ### Timezones
#
# Often, one can deduce national origin by simply looking at timezones.  This is helpful when analyzing entities that aren't large or old enough to have country data associated with it.  Here's the breakdown for this repo according to timezones.

# %%
Reagent().repo().timezones(repo_name).df()

# %% [markdown]
# ## Identity Verification
#
# One prime indicator of adversarial intent is the deliberate concealment of identity.  We have several methods to detect this in users.
#
# ### Timezone Manipulation
#
# Manipulating where you seem to be from is an indication of open source malpractice - specifically, manipulating your location incorrectly.  We can find instances of "teleportation" in our database by finding commits from different timezones impossibly close together in time.

# %%
Reagent().enrichments().timezone_spoof(repo_name).df()
# Out:
#   u.commit_count  u.tz_guess  \
# 0            824         8.0
# 1              2         5.5
# 2              2         8.0
# 3              2         8.0
# 4           3525        -0.0
# 5            630         8.0
# 6              2         8.0
# 7              2         8.0
# 8            139         8.0
# 9              2         8.0
#
#                                      u.email_address u.tz_most_common  \
# 0                                  jiangd@vmware.com              8.0
# 1                               yoyokvunal@gmail.com              5.5
# 2                                 noreply@github.com            28800
# 3                                 noreply@github.com            28800
# 4  49699333+dependabot[bot]@users.noreply.github.com              0.0
# 5                                 wangyan@vmware.com              8.0
# 6                                 noreply@github.com            28800
# 7                                 noreply@github.com            28800
# 8                               yshengwen@vmware.com              8.0
# 9                                 noreply@github.com            28800
#
#             u.name  u.first_commit_date._DateTime__date._Date__ordinal  \
# 0     Daniel Jiang                                           735995.0
# 1      kunal Dugar                                                NaN
# 2           GitHub                                           736124.0
# 3           GitHub                                           736124.0
# 4  dependabot[bot]                                           737411.0
# 5         Wang Yan                                           736396.0
# 6           GitHub                                           736124.0
# 7           GitHub                                           736124.0
# 8      Shengwen YU                                           737990.0
# 9           GitHub                                           736124.0
#
#    u.first_commit_date._DateTime__date._Date__year  \
# 0                                           2016.0
# 1                                              NaN
# 2                                           2016.0
# 3                                           2016.0
# 4                                           2019.0
# 5                                           2017.0
# 6                                           2016.0
# 7                                           2016.0
# 8                                           2021.0
# 9                                           2016.0
#
#    u.first_commit_date._DateTime__date._Date__month  \
# 0                                               2.0
# 1                                               NaN
# 2                                               6.0
# 3                                               6.0
# 4                                              12.0
# 5                                               3.0
# 6                                               6.0
# 7                                               6.0
# 8                                               7.0
# 9                                               6.0
#
#    u.first_commit_date._DateTime__date._Date__day  \
# 0                                             1.0
# 1                                             NaN
# 2                                             9.0
# 3                                             9.0
# 4                                            18.0
# 5                                             8.0
# 6                                             9.0
# 7                                             9.0
# 8                                            19.0
# 9                                             9.0
#
#    u.first_commit_date._DateTime__time._Time__ticks  ...  \
# 0                                      4.315000e+13  ...
# 1                                               NaN  ...
# 2                                      6.670600e+13  ...
# 3                                      6.670600e+13  ...
# 4                                      6.934800e+13  ...
# 5                                      2.778700e+13  ...
# 6                                      6.670600e+13  ...
# 7                                      6.670600e+13  ...
# 8                                      3.053700e+13  ...
# 9                                      6.670600e+13  ...
#
#    u.last_activity_at._DateTime__date._Date__year  \
# 0                                             NaN
# 1                                             NaN
# 2                                          2023.0
# 3                                          2023.0
# 4                                             NaN
# 5                                             NaN
# 6                                          2023.0
# 7                                          2023.0
# 8                                             NaN
# 9                                          2023.0
#
#    u.last_activity_at._DateTime__date._Date__month  \
# 0                                              NaN
# 1                                              NaN
# 2                                             12.0
# 3                                             12.0
# 4                                              NaN
# 5                                              NaN
# 6                                             12.0
# 7                                             12.0
# 8                                              NaN
# 9                                             12.0
#
#    u.last_activity_at._DateTime__date._Date__day  \
# 0                                            NaN
# 1                                            NaN
# 2                                           27.0
# 3                                           27.0
# 4                                            NaN
# 5                                            NaN
# 6                                           27.0
# 7                                           27.0
# 8                                            NaN
# 9                                           27.0
#
#    u.last_activity_at._DateTime__time._Time__ticks  \
# 0                                              NaN
# 1                                              NaN
# 2                                     3.017600e+13
# 3                                     3.017600e+13
# 4                                              NaN
# 5                                              NaN
# 6                                     3.017600e+13
# 7                                     3.017600e+13
# 8                                              NaN
# 9                                     3.017600e+13
#
#    u.last_activity_at._DateTime__time._Time__hour  \
# 0                                             NaN
# 1                                             NaN
# 2                                             8.0
# 3                                             8.0
# 4                                             NaN
# 5                                             NaN
# 6                                             8.0
# 7                                             8.0
# 8                                             NaN
# 9                                             8.0
#
#   u.last_activity_at._DateTime__time._Time__minute  \
# 0                                              NaN
# 1                                              NaN
# 2                                             22.0
# 3                                             22.0
# 4                                              NaN
# 5                                              NaN
# 6                                             22.0
# 7                                             22.0
# 8                                              NaN
# 9                                             22.0
#
#    u.last_activity_at._DateTime__time._Time__second  \
# 0                                               NaN
# 1                                               NaN
# 2                                              56.0
# 3                                              56.0
# 4                                               NaN
# 5                                               NaN
# 6                                              56.0
# 7                                              56.0
# 8                                               NaN
# 9                                              56.0
#
#   u.last_activity_at._DateTime__time._Time__nanosecond  u.tz_info u.hibp
# 0                                                NaN          NaN    NaN
# 1                                                NaN          NaN    NaN
# 2                                                0.0         None    NaN
# 3                                                0.0         None    NaN
# 4                                                NaN          NaN
# 5                                                NaN          NaN    NaN
# 6                                                0.0         None    NaN
# 7                                                0.0         None    NaN
# 8                                                NaN          NaN    NaN
# 9                                                0.0         None    NaN
#
# [10 rows x 211 columns]

# %% [markdown]
# ## Data Breaches
#
# Almost everyone in UnrealEngine has been a part of a database breach at one time or another - only 2.9% of users have been unbreached!  Here's what that looks like:

# %%
Reagent().enrichments().hibp(repo_name).df()
