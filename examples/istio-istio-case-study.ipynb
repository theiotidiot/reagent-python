# %% [markdown]
# # Istio / Proxy  Case Study
#
# This is a Reagent Analytics project demo, using the API, to answer questions about foreign influence in various entities in the Harbor open source project.
#
# The `reagentpy` Python package facilitates use of the [Reagent API](https://api.reagentanalytics.com) and querying the Reagent version control intelligence database.
#
# ## Import the `Reagent` object
#
# Set all required variable names to appropriately constrain query results.

# %%
from reagentpy import Reagent

repo = "istio/istio"
limit = 50
china_timezone = 8.0

# %% [markdown]
# # Non-Adversarial Threat
#
# There are a number of human factors that influence the likelihood that vulnerabilities are injected into repositories at various points in the open source lifecycle.  These can be used to infer threat that can be quantified, and thus analyzed.  These metrics are all on a sliding scale between from **0 - 10**, 0 meaning that Harbor is unaffected by this issue, and 10 meaning that that all commits exhibit the problem at hand.

# %%
Reagent().demo_visualizations().create_out_of_ten_chart(repo)

# %% [markdown]
# ## Threatscoring Breakdown
#
# **Project Fragmentation** is defined as the ratio of files within a repository edited by more than ten developers to files within a repository edited by less than ten developers.  The significance factor for this function is **r = 16**.
#
# **Unfocused Contribution** is measured by taking the average pagerank of each file within a repo.  The significance factor for this function is **r = .4497**.
#
# **Context Switching** is calculated by taking the average weekly density of distinct file communities users commit to each week.  The significance factor for this function is **r = 0.17**.
#
# **Interactive Churn** is the average weekly number of user interactions a file has, scaled by how recent each action is.  The significance factor for this function is **r = 0.16**.

# %%
Reagent().enrichments().threat_score(repo).df()
# Out:
#    interactive_churn_score  context_switching_score  \
# 0                     0.32                       10
#
#    project_fragmentation_score  unfocused_contribution_score
# 0                     0.905516                             0

# %% [markdown]
# ## What organizations are involved?  What are the affiliations of those organizations?
#
# Analyzing email domains found in the repo yeilds a glimpse into the organizations who are interested in using Harbor.

# %%
Reagent().demo_visualizations().wordcloud(repo)

# %%
Reagent().repo().email_domains(repo, limit).df()
# Out:
#       repo_name                    domain  instances  \
# 0   istio/istio                 gmail.com        444
# 1   istio/istio  users.noreply.github.com        286
# 2   istio/istio                google.com         86
# 3   istio/istio                    qq.com         33
# 4   istio/istio                redhat.com         29
# 5   istio/istio                huawei.com         18
# 6   istio/istio               daocloud.io         18
# 7   istio/istio                   solo.io         17
# 8   istio/istio               outlook.com         16
# 9   istio/istio                   163.com         14
# 10  istio/istio                us.ibm.com         14
# 11  istio/istio               hotmail.com         11
# 12  istio/istio                   sap.com         10
# 13  istio/istio                tetrate.io          9
# 14  istio/istio                 cisco.com          9
# 15  istio/istio                 intel.com          8
# 16  istio/istio                   126.com          8
# 17  istio/istio               foxmail.com          8
# 18  istio/istio             microsoft.com          7
# 19  istio/istio           alibaba-inc.com          6
# 20  istio/istio                 yahoo.com          6
# 21  istio/istio                   ibm.com          6
# 22  istio/istio                pivotal.io          5
# 23  istio/istio                inspur.com          5
# 24  istio/istio     volunteers.acasi.info          5
# 25  istio/istio             datadoghq.com          4
# 26  istio/istio            salesforce.com          4
# 27  istio/istio                   hpe.com          4
# 28  istio/istio               tencent.com          4
# 29  istio/istio                il.ibm.com          3
# 30  istio/istio                zte.com.cn          3
# 31  istio/istio                cn.ibm.com          3
# 32  istio/istio            googlemail.com          3
# 33  istio/istio                vmware.com          3
# 34  istio/istio                 alauda.io          3
# 35  istio/istio                airbnb.com          3
# 36  istio/istio                icloud.com          3
# 37  istio/istio                  ebay.com          3
# 38  istio/istio                   usc.edu          2
# 39  istio/istio                zju.edu.cn          2
# 40  istio/istio            beyondcent.com          2
# 41  istio/istio                apache.org          2
# 42  istio/istio           linux.intel.com          2
# 43  istio/istio                    me.com          2
# 44  istio/istio              aviatrix.com          2
# 45  istio/istio                github.com          2
# 46  istio/istio                  yeah.net          2
# 47  istio/istio           goingslowly.com          1
# 48  istio/istio                   live.de          1
# 49  istio/istio                  est.tech          1
#
#                                                                                                       timezones
# 0   [5.5, 8.0, -5.0, 11.0, -7.0, 9.0, 3.0, -8.0, -4.0, 13.0, 2.0, -6.0, 1.0, 7.0, -0.0, -3.0, 10.0, 12.0, -2.0]
# 1                      [-7.0, -5.0, -8.0, 1.0, 5.5, 8.0, 9.0, -4.0, 2.0, -0.0, 12.0, 6.0, -6.0, 3.0, 10.0, 7.0]
# 2                                                                  [-5.0, -8.0, 5.5, -7.0, -0.0, 1.0, 8.0, 2.0]
# 3                                                                                                         [8.0]
# 4                                                [2.0, 1.0, -5.0, 5.5, -4.0, -0.0, 8.0, -6.0, -8.0, -3.0, -7.0]
# 5                                                                                                         [8.0]
# 6                                                                                                         [8.0]
# 7                                                                                 [-4.0, -7.0, 2.0, -6.0, -5.0]
# 8                                                                        [-7.0, 1.0, 8.0, 5.5, 9.0, -4.0, -5.0]
# 9                                                                                                         [8.0]
# 10                                                                                     [-5.0, -4.0, -0.0, -7.0]
# 11                                                                             [-4.0, 1.0, 3.0, 8.0, 9.0, -7.0]
# 12                                                                                                   [2.0, 1.0]
# 13                                                                             [5.5, 2.0, 1.0, 9.0, -6.0, -7.0]
# 14                                                                                     [-4.0, -7.0, -8.0, -5.0]
# 15                                                                                             [8.0, 2.0, -8.0]
# 16                                                                                                        [8.0]
# 17                                                                                                  [8.0, -0.0]
# 18                                                                               [-5.0, -4.0, -7.0, -8.0, -6.0]
# 19                                                                                                        [8.0]
# 20                                                                               [-10.0, 8.0, -4.0, -5.0, -7.0]
# 21                                                                                      [1.0, -7.0, -4.0, -6.0]
# 22                                                                                                  [-7.0, 1.0]
# 23                                                                                                        [8.0]
# 24                                                                                                       [-6.0]
# 25                                                                                                 [12.0, -4.0]
# 26                                                                                                  [5.5, -7.0]
# 27                                                                                             [-3.0, 2.0, 1.0]
# 28                                                                                                        [8.0]
# 29                                                                                                   [3.0, 2.0]
# 30                                                                                                        [8.0]
# 31                                                                                                        [8.0]
# 32                                                                                                  [2.0, -4.0]
# 33                                                                                           [-3.0, -7.0, -4.0]
# 34                                                                                                        [8.0]
# 35                                                                                                       [-7.0]
# 36                                                                                             [9.0, 8.0, -7.0]
# 37                                                                                                  [8.0, -7.0]
# 38                                                                                                       [-7.0]
# 39                                                                                                        [8.0]
# 40                                                                                                        [8.0]
# 41                                                                                                   [8.0, 1.0]
# 42                                                                                                        [2.0]
# 43                                                                                                        [1.0]
# 44                                                                                                       [-7.0]
# 45                                                                                                  [-5.0, 1.0]
# 46                                                                                                        [8.0]
# 47                                                                                                       [-4.0]
# 48                                                                                                        [2.0]
# 49                                                                                                        [2.0]

# %% [markdown]
# ## Repository Health
#
# Here are some indications of whether or not an open source repository is well-maintained, and is following the most basic security guidelines set by GitHub.
#
# This endpoint is not currently available, but we anticipate that it will be ready shortly.

# %%
Reagent().demo_visualizations().print_hygiene_summary(repo)
# Out:
# Repository Overview: istio/istio
# Description: Connect, secure, control, and observe services.
# Total Contributors: 1320, spanning across 23 timezones, indicating a global contribution pattern.
# Fork Count: 7848, showcasing immense community engagement and interest.
# License Presence: Present, a necessary aspect of open source contribution.
# Readme Presence: Present, vital for repository documentation.
# Recent Activity: The repository was last active on 2025-02-24, indicating an active status.

# %%
Reagent().repo().hygiene_summary(repo).df()
# Out:
#                                        description  forks  has_license  \
# 0  Connect, secure, control, and observe services.   7848         True
#
#      repo_name  has_readme  \
# 0  istio/istio        True
#
#                                                                                                                             timezones  \
# 0  [-8.0, -7.0, -4.0, -5.0, -0.0, 8.0, 2.0, -6.0, 5.5, 1.0, 3.0, 11.0, 7.0, 9.0, 13.0, 10.0, -3.0, 12.0, 6.0, -10.0, 4.0, -9.0, -2.0]
#
#    total_contributors  total_timezones last_activity_at
# 0                1320               23       2025-02-24

# %% [markdown]
# # Adversarial Risk
#
# Describes deliberate attacks by bad actors with intent, capability, and targeting characteristics of any scale.  While all kinds of risk are invaluable in deciding how "safe" a resource is to use, adversarial risk serves as the best way to quantify sources of attack.
#
# ### Timezones
#
# Often, one can deduce national origin by simply looking at timezones.  This is helpful when analyzing entities that aren't large or old enough to have country data associated with it.  Here's the breakdown for this repo according to timezones.

# %%
Reagent().timezone_visualizations().build_and_show_timezone_map(repo)

# %%
Reagent().timezone_visualizations().plot_timezone_distribution_color(repo)

# %%
Reagent().timezone_visualizations().show_logarithmic_bar_chart(repo)

# %%
Reagent().repo().timezones(repo).df()['timezone_commit_totals'][0]
# Out:
# [{'timezone': -7.0, 'total_commits': 7027},
#  {'timezone': -5.0, 'total_commits': 3784},
#  {'timezone': 5.5, 'total_commits': 1088},
#  {'timezone': -8.0, 'total_commits': 5551},
#  {'timezone': 1.0, 'total_commits': 386},
#  {'timezone': 8.0, 'total_commits': 3572},
#  {'timezone': 2.0, 'total_commits': 759},
#  {'timezone': -4.0, 'total_commits': 1756},
#  {'timezone': -6.0, 'total_commits': 200},
#  {'timezone': 11.0, 'total_commits': 4},
#  {'timezone': 9.0, 'total_commits': 84},
#  {'timezone': 3.0, 'total_commits': 146},
#  {'timezone': 13.0, 'total_commits': 10},
#  {'timezone': -0.0, 'total_commits': 121},
#  {'timezone': 7.0, 'total_commits': 14},
#  {'timezone': -3.0, 'total_commits': 40},
#  {'timezone': 12.0, 'total_commits': 9},
#  {'timezone': 6.0, 'total_commits': 1},
#  {'timezone': -10.0, 'total_commits': 1},
#  {'timezone': 10.0, 'total_commits': 8},
#  {'timezone': 4.0, 'total_commits': 1},
#  {'timezone': -9.0, 'total_commits': 1},
#  {'timezone': -2.0, 'total_commits': 1}]

# %% [markdown]
# ## Identity Verification
#
# One prime indicator of adversarial intent is the deliberate concealment of identity.  We have several methods to detect this in users.
#
# ### Timezone Manipulation
#
# Manipulating where you seem to be from is an indication of open source malpractice - specifically, manipulating your location incorrectly.  We can find instances of "teleportation" in our database by finding commits from different timezones impossibly close together in time.

# %%
Reagent().enrichments().timezone_spoof(repo).df()
# Out:
#    spoof_score  tz_1  tz_2                             email  \
# 0         15.0  -7.0   8.0             howardjohn@google.com
# 1         15.0  -7.0   8.0             howardjohn@google.com
# 2         10.0  -8.0   2.0               yangguan@google.com
# 3         10.0   2.0  -8.0  zcahana@users.noreply.github.com
# 4         10.0   3.0  -7.0                 vadime@il.ibm.com
# 5          9.0   1.0  -8.0               joerg@mesosphere.io
# 6          7.0  -5.0   2.0                 frankb@ca.ibm.com
# 7          7.0  -4.0   3.0                 linsun@us.ibm.com
# 8          7.0  -7.0  -0.0                 jaksic@google.com
# 9          7.0   2.0  -5.0                 vadime@il.ibm.com
#
#                                                                     url_1  \
# 0  github.com/istio/istio/commit/31f451bd96d0c7390c62a62890728ba00fda2a10
# 1  github.com/istio/istio/commit/867dab01ac7380b0c43468bef6352174ebbc80d8
# 2  github.com/istio/istio/commit/6323a4bd94018ad0679be621ad3e40ecf0afd3ff
# 3  github.com/istio/istio/commit/f54c6f2ff2fb02d17b65be01a4f066e0b0b5ef67
# 4  github.com/istio/istio/commit/9b7706817bb0cf895c6a0e733ae09497897f0ddc
# 5  github.com/istio/istio/commit/1903f78ae8441432ff76052aa88f80cd5e3dd7cd
# 6  github.com/istio/istio/commit/5fdabc963947e5eb52ba08d455a48d328f806305
# 7  github.com/istio/istio/commit/e1a1a9d2b99fc122cbff303bbf8c9a179d6553cb
# 8  github.com/istio/istio/commit/7afac8bf4ebbddeff70e5c7660fe2071e7237a6a
# 9  github.com/istio/istio/commit/9418e11231d790ffc99be4e17f8bc0852a8102cb
#
#                                                                     url_2  \
# 0  github.com/istio/istio/commit/431d91c96e537ec5daf78ee38d66349cb1951836
# 1  github.com/istio/istio/commit/1ee1e45542005ba2d4aca0d5b21724a181f616b2
# 2  github.com/istio/istio/commit/479157ad6254af22b9cea4e581ed42b51a25ea8f
# 3  github.com/istio/istio/commit/ddd0a73ca925c5e42dea5b809945c26b3b76b439
# 4  github.com/istio/istio/commit/f301484df18a5694ce6b93d273f3081a0a5c167b
# 5  github.com/istio/istio/commit/910d8b2747ced604961d899e02dffe0c4a5214a4
# 6  github.com/istio/istio/commit/e59bac09f3ba7c2494728e76bf7b74e5b75dbc06
# 7  github.com/istio/istio/commit/98c27041eae05fde958035cec029c24e8291fb39
# 8  github.com/istio/istio/commit/eb42c59afd2af3751bfb3c2e6ea7812bffa177d7
# 9  github.com/istio/istio/commit/40908ec6265b3681808c242a02301fc413700e43
#
#    commit_1_date._Date__ordinal  commit_1_date._Date__year  \
# 0                        737237                       2019
# 1                        737241                       2019
# 2                        736389                       2017
# 3                        736389                       2017
# 4                        736831                       2018
# 5                        736660                       2017
# 6                        736376                       2017
# 7                        736829                       2018
# 8                        736632                       2017
# 9                        736712                       2018
#
#    commit_1_date._Date__month  commit_1_date._Date__day  \
# 0                           6                        27
# 1                           7                         1
# 2                           3                         1
# 3                           3                         1
# 4                           5                        17
# 5                          11                        27
# 6                           2                        16
# 7                           5                        15
# 8                          10                        -2
# 9                           1                        18
#
#    commit_2_date._Date__ordinal  commit_2_date._Date__year  \
# 0                        737237                       2019
# 1                        737242                       2019
# 2                        736389                       2017
# 3                        736389                       2017
# 4                        736831                       2018
# 5                        736660                       2017
# 6                        736376                       2017
# 7                        736829                       2018
# 8                        736632                       2017
# 9                        736712                       2018
#
#    commit_2_date._Date__month  commit_2_date._Date__day
# 0                           6                        27
# 1                           7                         2
# 2                           3                         1
# 3                           3                         1
# 4                           5                        17
# 5                          11                        27
# 6                           2                        16
# 7                           5                        15
# 8                          10                        -2
# 9                           1                        18

# %%
Reagent().demo_visualizations().adversarial_pie_chart(repo)
